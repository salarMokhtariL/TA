# %% [markdown]
# ![cf55489ccd434e8c81c61e6fffc9433f.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Set Up pyhton Interpreter
#
# You can download the prope version of Python [here](https://www.python.org/downloads/)

# %% [markdown]
# # Hello world
#
#
# you can print function for console out put

# %%
print("Hello world")
print(2022)
print("Hello world", 2022)
# Out:
# Hello world
# 2022
# Hello world 2022

# %% [markdown]
# # Variable
#
# In the variable declaration in python is by value assignment,In the other word, there is no difference between variable declaration and value

# %%
i = 850            #type : int 
f = 5.6            #type : float
d = 5.8448844578   #type : float
s = "LA"           #type : str
b = False          #type : bool
t = (1, 2.1, 'LA') #type : tuple

# %% [markdown]
# You can use `type` function to identify type of a variable

# %% [markdown]
# # Type Cast
#
# You can use function like int, float or str to apply type cast

# %%
simple_integeer = 23 
simple_float = 52.25


string_integeer = str(simple_integeer)            #Cast int to string 
string_float = str(simple_float)                  #Cast float to string


upside_downInt = int(string_integeer)             #Cast string to int 
upside_downFloat = float(string_float)            #Cast string to float




print(string_integeer)
print( string_float) 


print(upside_downInt)
print(upside_downFloat)

# %% [markdown]
# ## What is the difference between **'Comments'** and **'Docstring'**?

# %% [markdown]
# # Std input
#
# you can use `input` function to get input from console. value of input function is always a variable with `str` type

# %%
i = input()
print(i)
i1 = int(i)
print(type(i1))
# Out:
# 25
# 25
# <class 'int'>

# %% [markdown]
# ---
# ---
#
#
# # Arithmetic operators
# We some new operators. other arithmetic operators are just like languages like C or Java

# %%
a = 8
b = 2.5

r1 = a + b              # addition 
r2 = a - b              # subtraction
r3 = a * b              # multiplication
r4 = a / b              # division 
r5 = a % b              # modulus


r6 = a // b             
r7 = a ** b

# %%
# Assignment operators

a = 10


a += 1
a -= 1
a *= 2
a /= 2
a %= 3

b = 2

b //= 2
b **= 2

# %% [markdown]
# # Comparsion operators

# %%
x = 1
y = 2
z = 3


c1 = x == y               # Equals
c2 = x != y               # Not Equals
c3 = x < y                # Less than
x <= y               # Less than or equal to

x < y <= z
# Out:
# True

# %% [markdown]
# # Logic operators

# %%
# Bool tpyes
p = True
q = False


# Boolean operators 
bo1 = not p
bo2 = p and q
bo3 = p or q

# Identity operators Is & Is not


# Membership operators in & not in


# Bitwise operators 

'''
  & --- AND
  | --- OR
  ~ --- NOT
  ^ --- XOR
  << -- Zero Left Shift 
  >> -- Signed Right Shift 
'''

bo4 = 1 & 2
bo5 = 1 | 2
bo6 = 1 ^ 2     # XOR
bo7 = ~1

# %% [markdown]
# # Conditional Statement
#
# These conditions can be used in several ways, most commonly in "if statements" and loops.
#
# An "if statement" is written by using the `if` keyword.

# %%
a = 15
b = 5
if a > b :
    print(a , " is greater than" , b)
# Out:
# 15  is greater than 5

# %% [markdown]
# ## Elif
#
# The `elif` keyword is pythons way of saying "if the previous conditions were not true, then try this condition".

# %%
if a < b :
     print(a , " is less than" , b)
elif a > b:
     print(a , " is greater than" , b)
# Out:
# 15  is greater than 5

# %% [markdown]
# ## Else
#
# The `else` keyword catches anything which isn't caught by the preceding conditions.

# %%
if a < b :
     print(a , " is less than" , b)
elif a > b:
      print(a , " is greater than" , b)
else:
     print(a, " and ", b ,"are equal")
# Out:
# 15  is greater than 5

# %% [markdown]
# # Short Hand If
# If you have only one statement to execute, you can put it on the same line as the if statement.

# %%
 if a > b: print("a is greater than b")

# %% [markdown]
# ## The pass Statement
#
# if statements cannot be empty, but if you for some reason have an if statement with no content, put in the pass statement to avoid getting an error.

# %%
if a > b:
  pass

# %% [markdown]
# # While Loop
#
# with the `while` loop we can execute as set of statements as long as condition is true .
#
#
# ```
# i = 1
# while i < 6 :
#   print(i)
#   i += 1
# ```
# ## The break Statement
#
# with the `break` statement we can stop the loop even if the while condition is true :

# %%
i = 1
while i < 6 :
  print(i)
  if i == 3 :
    break
  i += 1
# Out:
# 1
# 2
# 3

# %%
# Continue Statement 

i = 0 
while i < 6 :
  i += 1
  if i == 3 :
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %%
# Else Statement 

i = 1 
while i < 6 :
  print(i)
  i += 1
else :
  print("i is no longer less than 6")

# %% [markdown]
# # Python For Loops
# A `for` loop is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string).
#
# This is less like the `for` keyword in other programming languages, and works more like an iterator method as found in other object-orientated programming languages.
#
# With the `for` loop we can execute a set of statements, once for each item in a list, tuple, set etc.

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
